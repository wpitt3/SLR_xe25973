# %%
# %load_ext autoreload
# %autoreload 2
from pose_utils import (
    load_dataset_file, load_csl_pose_pkl, load_csl_news_folder,
    GROUPS, GROUP_COLORS, MSKA_KEYPOINTS,
    compute_group_confidence_histograms, plot_confidence_distribution, plot_compare_confidence_distribution,
)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
csl_daily = load_dataset_file("../data/RTM/CSL-Daily.train")

# %%
csl_news, skipped = load_csl_news_folder("../data/CSL_News/pose_format", max_files=20000)
# Out:
# Loaded: 20000, Skipped: 0

# %%
_, ax = plot_compare_confidence_distribution(csl_news, csl_daily, "CSL-News ", "CSL-Daily ", True, title="Distribution of RTMPose encoding keypoint confidence, of the hands from CSL-Daily")
ax.figure.savefig(f"../latex/CSL_confidence.png", dpi=300, bbox_inches="tight")

# %%
# Out:
# S000000_P0000_T00
# torch.Size([84, 133, 3])
